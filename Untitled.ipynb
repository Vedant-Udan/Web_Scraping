# %%
# import requests
# from bs4 import BeautifulSoup
# conda install -c anaconda beautifulsoup4
# !pip install bs4
# !pip install --upgrade pip
# !pip install pandas
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 13.2 MB/s eta 0:00:00m eta 0:00:010:0110m
# ...
#   Using cached pytz-2022.7-py2.py3-none-any.whl (499 kB)
# ...
#   Using cached numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# ...

# %%
import requests
from bs4 import BeautifulSoup
from csv import writer
import pandas as pd

# %%
url = "https://www.flipkart.com/search?q=iphones&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

# %%
r = requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.content,"html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
lists = soup.find_all("div", class_="_1AtVbE col-12-12")
print(lists)
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphones&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy,
# ...

# %%
print(len(lists))
# Out:
# 30

# %%
name = lists[5].find("div",class_="_4rR01T").text
print(name)
Rom = lists[5].find("li",class_="rgWa7D").text
print(Rom)
display= lists[5].find("ul",class_="_1xgFaf").findChildren()[2].text
print(display)
# Out:
# APPLE iPhone 14 (Purple, 128 GB)
# 128 GB ROM
# 12MP + 12MP | 12MP Front Camera

# %%
with open("iphone.csv","w",encoding ="utf8",newline = "") as f:
    thewriter = writer(f)
    header =["Name","Rom","Screen","Camera","Processor","Price"]
    thewriter.writerow(header)
    for list in lists:
        name = list.find("div",class_="_4rR01T")
        if name == None:
            pass
        else:
            l = [name.text]
            for i in range(4):
                l.append(list.find("ul",class_="_1xgFaf").findChildren()[i].text)
            l.append(list.find("div",class_="_30jeq3 _1_WHN1").text)
            thewriter.writerow(l)

# %%
df = pd.read_csv("iphone.csv")
df.head()
# Out:
#                                   Name         Rom  \
# 0       APPLE iPhone 14 (Blue, 128 GB)  128 GB ROM
# 1   APPLE iPhone 14 (Midnight, 128 GB)  128 GB ROM
# 2  APPLE iPhone 14 (Starlight, 128 GB)  128 GB ROM
# 3     APPLE iPhone 14 (Purple, 128 GB)  128 GB ROM
# 4  APPLE iPhone 13 (Starlight, 128 GB)  128 GB ROM
#
#                                          Screen  \
# 0  15.49 cm (6.1 inch) Super Retina XDR Display
# 1  15.49 cm (6.1 inch) Super Retina XDR Display
# 2  15.49 cm (6.1 inch) Super Retina XDR Display
# 3  15.49 cm (6.1 inch) Super Retina XDR Display
# 4  15.49 cm (6.1 inch) Super Retina XDR Display
#
#                             Camera  \
# 0  12MP + 12MP | 12MP Front Camera
# 1  12MP + 12MP | 12MP Front Camera
# 2  12MP + 12MP | 12MP Front Camera
# 3  12MP + 12MP | 12MP Front Camera
# 4  12MP + 12MP | 12MP Front Camera
#
#                                      Processor    Price
# 0  A15 Bionic Chip, 6 Core Processor Processor  ₹73,990
# ...
